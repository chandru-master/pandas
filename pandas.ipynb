# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/chandraprakash/Documents/EDA/HousePrices.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
df.tail(1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1459         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1459      6   2008        WD         Normal     147500
#
# [1 rows x 81 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df[100:125] #includes row number 100 but not inclused row number 125
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 100  101          20       RL          NaN    10603   Pave   NaN      IR1
# 101  102          60       RL         77.0     9206   Pave   NaN      Reg
# 102  103          90       RL         64.0     7018   Pave   NaN      Reg
# 103  104          20       RL         94.0    10402   Pave   NaN      IR1
# 104  105          50       RM          NaN     7758   Pave   NaN      Reg
# 105  106          60       FV         75.0     9375   Pave   NaN      Reg
# 106  107          30       RM         60.0    10800   Pave  Grvl      Reg
# 107  108          20       RM         50.0     6000   Pave   NaN      Reg
# 108  109          50       RM         85.0     8500   Pave   NaN      Reg
# 109  110          20       RL        105.0    11751   Pave   NaN      IR1
# 110  111          50       RL         75.0     9525   Pave   NaN      Reg
# 111  112          80       RL          NaN     7750   Pave   NaN      IR1
# ...

# %%
df[:2]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
df.LotArea # column name print
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
type(df['LotArea'])
# Out:
# pandas.core.series.Series

# %%
df[['LotArea','Neighborhood']]
# Out:
#       LotArea Neighborhood
# 0        8450      CollgCr
# 1        9600      Veenker
# 2       11250      CollgCr
# 3        9550      Crawfor
# 4       14260      NoRidge
# ...       ...          ...
# 1455     7917      Gilbert
# 1456    13175       NWAmes
# 1457     9042      Crawfor
# 1458     9717        NAmes
# 1459     9937      Edwards
#
# [1460 rows x 2 columns]

# %%
df['LotArea'].max()
# Out:
# 215245

# %%
df['LotArea'].mean()
# Out:
# 10516.828082191782

# %%
df['LotArea'].min()
# Out:
# 1300

# %%
df['LotArea'].count()
# Out:
# 1460

# %%
df['LotArea'].std()
# Out:
# 9981.264932379147

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df[df.LotArea>=15000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 41      42          20       RL        115.0    16905   Pave   NaN      Reg
# 53      54          20       RL         68.0    50271   Pave   NaN      IR1
# 66      67          20       RL          NaN    19900   Pave   NaN      Reg
# 69      70          50       RL         81.0    15593   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
#
# ...

# %%
df[df.LotArea==14000]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 299    300          20       RL         80.0    14000   Pave   NaN      Reg
# 1065  1066          60       RL         80.0    14000   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 299          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 1065         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 299       8   2009        WD         Family     158500
# 1065      4   2010        WD         Normal     328000
#
# [2 rows x 81 columns]

# %%
df[df.LotArea==df['LotArea'].max()]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313  314          20       RL        150.0   215245   Pave   NaN      IR3
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 313         Low    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 313      6   2009        WD         Normal     375000
#
# [1 rows x 81 columns]

# %%
df['Id'][df.LotArea==df['LotArea'].max()]
# Out:
# 313    314
# Name: Id, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
df.set_index('LotArea')
# Out:
#            Id  MSSubClass MSZoning  LotFrontage Street Alley LotShape  \
# LotArea
# 8450        1          60       RL         65.0   Pave   NaN      Reg
# 9600        2          20       RL         80.0   Pave   NaN      Reg
# 11250       3          60       RL         68.0   Pave   NaN      IR1
# 9550        4          70       RL         60.0   Pave   NaN      IR1
# 14260       5          60       RL         84.0   Pave   NaN      IR1
# ...       ...         ...      ...          ...    ...   ...      ...
# 7917     1456          60       RL         62.0   Pave   NaN      Reg
# 13175    1457          20       RL         85.0   Pave   NaN      Reg
# 9042     1458          70       RL         66.0   Pave   NaN      Reg
# 9717     1459          20       RL         68.0   Pave   NaN      Reg
# 9937     1460          20       RL         75.0   Pave   NaN      Reg
#
#         LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence  \
# LotArea                                  ...
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.set_index('Id')
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.set_index('Id',inplace= True)

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.reset_index(inplace=True)#to reset the index

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
df.set_index('HouseStyle', inplace=True)

# %%
df
# Out:
#             level_0  index    Id  MSSubClass MSZoning  LotFrontage  LotArea  \
# HouseStyle
# 2Story            0      0     1          60       RL         65.0     8450
# 1Story            1      1     2          20       RL         80.0     9600
# 2Story            2      2     3          60       RL         68.0    11250
# 2Story            3      3     4          70       RL         60.0     9550
# 2Story            4      4     5          60       RL         84.0    14260
# ...             ...    ...   ...         ...      ...          ...      ...
# 2Story         1455   1455  1456          60       RL         62.0     7917
# 1Story         1456   1456  1457          20       RL         85.0    13175
# 2Story         1457   1457  1458          70       RL         66.0     9042
# 1Story         1458   1458  1459          20       RL         68.0     9717
# 1Story         1459   1459  1460          20       RL         75.0     9937
#
# ...

# %%
df.loc['2Story']
# Out:
#             level_0  index    Id  MSSubClass MSZoning  LotFrontage  LotArea  \
# HouseStyle
# 2Story            0      0     1          60       RL         65.0     8450
# 2Story            2      2     3          60       RL         68.0    11250
# 2Story            3      3     4          70       RL         60.0     9550
# 2Story            4      4     5          60       RL         84.0    14260
# 2Story            7      7     8          60       RL          NaN    10382
# ...             ...    ...   ...         ...      ...          ...      ...
# 2Story         1447   1447  1448          60       RL         80.0    10000
# 2Story         1448   1448  1449          50       RL         70.0    11767
# 2Story         1450   1450  1451          90       RL         60.0     9000
# 2Story         1455   1455  1456          60       RL         62.0     7917
# 2Story         1457   1457  1458          70       RL         66.0     9042
#
# ...

# %%
#Different Ways Of Creating DataFrame

import pandas as pd

# %%
#df1 = pd.read_csv
#df2 = pd.read_excel('topic','sheet1')
#dictionary method
#House_prices = {
    #'Id':[1,2,3],
   # 'MSSubClass':[60,20,60],
   # 'LotArea':[8450,9600,11250],
   # 'SaleCondition':['Normal','Abnormal','Normal']}
#df = pd.DataFrame(House_prices)
#df
#tuples method each element is the list called tuples
House_prices2 = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',12,7,'snow')]

df = pd.DataFrame (House_prices2 ,columns= ['Date','temp','windspeed','event'])
df
# Out:
#        Date  temp  windspeed event
# 0  1/1/2017    32          6  Rain
# 1  1/2/2017    12          7  snow

# %%
df = pd.read_csv("C:/Users/chandraprakash/Documents/EDA/HousePrices.csv") #(skiprows=1,header=None,names=['column names'],nrows=3)

# %%
#everthing inside the pd.read_files("filename",everycodes)
#na_values=["nullvalues mentioned in the data"]
#index=False
# read_excel
# how to eliminate the null values
# def convert_columnname_cell(cell)
  #if cell=="n.a values":
      #return none
  #return cell
#df = pd.read_excel("file_name", sheet1,converters = {
           #columnname:convert_columnname_cell })

# %%
#how to fill the null values and the replace the null values 
#new_df = df.fillna(values need to pass)
#new_df

#replce
#new_df = df.fillna({
   #'column names': values,
    #'column names': values })
#new_df
#new_df = df.fillna(method="ffill")
#new_df = df.fillna(method="bfill")
#new_df = df.fillna(method="bfill",limit=2 , axis= "colums")

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
#new_df = df.interpolate()
#new_df

# %%
#new_df = df.interpolate(method="time")
#new_df

# %%
#if two null value is there it wont show the entire row
#new_df = df.dropna(thresh=2)
#new_df

# %%
#drop the null values
new_df = df.dropna()
new_df
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
new_df = df.dropna(how = "all")
new_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#now we gonna see how to replace the data:

import pandas as pd

# %%
import numpy as np

# %%
my_data = [
    ('1/1/2017',60,56,'maths'),
    ('1/2/2017',70,61,'science'),
    ('1/3/2017',80,72,'social')]

df = pd.DataFrame (my_data ,columns= ['examDate','totalmarks','scored','sub'])
df
# Out:
#    examDate  totalmarks  scored      sub
# 0  1/1/2017          60      56    maths
# 1  1/2/2017          70      61  science
# 2  1/3/2017          80      72   social

# %%
new_data=df.replace(70,np.NaN)
new_data
# Out:
#    examDate  totalmarks  scored      sub
# 0  1/1/2017        60.0      56    maths
# 1  1/2/2017         NaN      61  science
# 2  1/3/2017        80.0      72   social

# %%
#how to replace to two values to make list for that
new_data=df.replace([70,61],np.NaN)
new_data
# Out:
#    examDate  totalmarks  scored      sub
# 0  1/1/2017        60.0    56.0    maths
# 1  1/2/2017         NaN     NaN  science
# 2  1/3/2017        80.0    72.0   social

# %%
new_data = df.replace({
    'totalmarks':'NaN',
    'scored': 'NaN'
},np.NaN)
new_data
# Out:
#    examDate  totalmarks  scored      sub
# 0  1/1/2017          60      56    maths
# 1  1/2/2017          70      61  science
# 2  1/3/2017          80      72   social

# %%
new_data = df.replace({
    'totalmarks': 70,
    'scored': 61
},np.NaN)
new_data
# Out:
#    examDate  totalmarks  scored      sub
# 0  1/1/2017        60.0    56.0    maths
# 1  1/2/2017         NaN     NaN  science
# 2  1/3/2017        80.0    72.0   social

# %%
# if there is any alphabatical character then we need to use this type of codes

# %%
new_data = df.replace('[A-Za-z]','',regex=True)
new_data
# Out:
#    examDate  totalmarks  scored sub
# 0  1/1/2017          60      56
# 1  1/2/2017          70      61
# 2  1/3/2017          80      72

# %%
# using group by method in pandas
import pandas as pd

# %%
sales_man = pd.read_csv('C:/Users/chandraprakash/Documents/salesman.csv')
sales_man
# Out:
#          date      city       Job  Salary
# 0  05-02-2017  New York  Software   12000
# 1  05-03-2018  New York  Hardware   11500
# 2  06-02-2017  New York  Mechanic   13000
# 3  07-02-2017  New York      Chef   14000
# 4  20-02-2017     Paris  Hardware   12500
# 5  21-02-2018     Paris  Mechanic   13500
# 6  21-05-2018     Paris      Chef   11000
# 7  21-05-2018    London  Software   15000
# 8  05-03-2018    London      Chef   12000
# 9  05-02-2017    London  Mechanic   14500

# %%
g = sales_man.groupby('city')
g

# %%
for city,city_sales_man in g:
    print(city)
    print(city_sales_man)
# Out:
# London
#    salesman_id              name    city       Job  Salary
# 7         5008          Pit Alex  London  Software   15000
# 8         5009         Paul Adam  London      Chef   12000
# 9         5010  George Washigton  London  Mechanic   14500
# New York
#    salesman_id          name      city       Job  Salary
# 0         5001    James Hoog  New York  Software   12000
# 1         5002    Lauson Hen  New York  Hardware   11500
# 2         5003  Chris Wilson  New York  Mechanic   13000
# 3         5004   Hena Trusty  New York      Chef   14000
# Paris
#    salesman_id        name   city       Job  Salary
# 4         5005  Nail Knite  Paris  Hardware   12500
# 5         5006     Mc Lyon  Paris  Mechanic   13500
# 6         5007   Jin White  Paris      Chef   11000

# %%
g.get_group('New York')
# Out:
#    salesman_id          name      city       Job  Salary
# 0         5001    James Hoog  New York  Software   12000
# 1         5002    Lauson Hen  New York  Hardware   11500
# 2         5003  Chris Wilson  New York  Mechanic   13000
# 3         5004   Hena Trusty  New York      Chef   14000

# %%
g.mean('Salary')
# Out:
#           salesman_id        Salary
# city
# London         5009.0  13833.333333
# New York       5002.5  12625.000000
# Paris          5006.0  12333.333333

# %%
g.max()
# Out:
#           salesman_id        name       Job  Salary
# city
# London           5010    Pit Alex  Software   15000
# New York         5004  Lauson Hen  Software   14000
# Paris            5007  Nail Knite  Mechanic   13500

# %%
g.min()
# Out:
#           salesman_id              name   Job  Salary
# city
# London           5008  George Washigton  Chef   12000
# New York         5001      Chris Wilson  Chef   11500
# Paris            5005         Jin White  Chef   11000

# %%
g.plot()
# Out:
# city
# London      AxesSubplot(0.125,0.125;0.775x0.755)
# New York    AxesSubplot(0.125,0.125;0.775x0.755)
# Paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# London      AxesSubplot(0.125,0.125;0.775x0.755)
# New York    AxesSubplot(0.125,0.125;0.775x0.755)
# Paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
us_weather = pd.DataFrame({
    "city": ['newyork','washington','newjersey','illinois'],
    "temperature" : [32,14,25,31],
    "humidity": [61,65,68,61]
})
us_weather
# Out:
#          city  temperature  humidity
# 0     newyork           32        61
# 1  washington           14        65
# 2   newjersey           25        68
# 3    illinois           31        61

# %%
df = pd.concat([us_weather,sales_man])

# %%
df
# Out:
#          city  temperature  humidity  salesman_id              name       Job  \
# 0     newyork         32.0      61.0          NaN               NaN       NaN
# 1  washington         14.0      65.0          NaN               NaN       NaN
# 2   newjersey         25.0      68.0          NaN               NaN       NaN
# 3    illinois         31.0      61.0          NaN               NaN       NaN
# 0    New York          NaN       NaN       5001.0        James Hoog  Software
# 1    New York          NaN       NaN       5002.0        Lauson Hen  Hardware
# 2    New York          NaN       NaN       5003.0      Chris Wilson  Mechanic
# 3    New York          NaN       NaN       5004.0       Hena Trusty      Chef
# 4       Paris          NaN       NaN       5005.0        Nail Knite  Hardware
# 5       Paris          NaN       NaN       5006.0           Mc Lyon  Mechanic
# 6       Paris          NaN       NaN       5007.0         Jin White      Chef
# ...

# %%
df = pd.concat([us_weather,sales_man], ignore_index=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-16b1b0ad1d70> in <module>
# ----> 1 df = pd.concat([us_weather,sales_man], ignore_index=True)
#       2 df
#
# NameError: name 'sales_man' is not defined

# %%
df = pd.concat([us_weather,sales_man], ignore_index=True , keys=["us","man"])
df
# Out:
#           city  temperature  humidity  salesman_id              name  \
# 0      newyork         32.0      61.0          NaN               NaN
# 1   washington         14.0      65.0          NaN               NaN
# 2    newjersey         25.0      68.0          NaN               NaN
# 3     illinois         31.0      61.0          NaN               NaN
# 4     New York          NaN       NaN       5001.0        James Hoog
# 5     New York          NaN       NaN       5002.0        Lauson Hen
# 6     New York          NaN       NaN       5003.0      Chris Wilson
# 7     New York          NaN       NaN       5004.0       Hena Trusty
# 8        Paris          NaN       NaN       5005.0        Nail Knite
# 9        Paris          NaN       NaN       5006.0           Mc Lyon
# 10       Paris          NaN       NaN       5007.0         Jin White
# 11      London          NaN       NaN       5008.0          Pit Alex
# 12      London          NaN       NaN       5009.0         Paul Adam
# ...

# %%
new_df = df.fillna({
     "temperature": 0,
      "humidity": 0,"salesman_id": 0,
    })
new_df
# Out:
#           city  temperature  humidity  salesman_id              name  \
# 0      newyork         32.0      61.0          0.0               NaN
# 1   washington         14.0      65.0          0.0               NaN
# 2    newjersey         25.0      68.0          0.0               NaN
# 3     illinois         31.0      61.0          0.0               NaN
# 4     New York          0.0       0.0       5001.0        James Hoog
# 5     New York          0.0       0.0       5002.0        Lauson Hen
# 6     New York          0.0       0.0       5003.0      Chris Wilson
# 7     New York          0.0       0.0       5004.0       Hena Trusty
# 8        Paris          0.0       0.0       5005.0        Nail Knite
# 9        Paris          0.0       0.0       5006.0           Mc Lyon
# 10       Paris          0.0       0.0       5007.0         Jin White
# 11      London          0.0       0.0       5008.0          Pit Alex
# 12      London          0.0       0.0       5009.0         Paul Adam
# ...

# %%
import pandas as pd

# %%
new_df = pd.concat([us_weather,sales_man], axis=1)
new_df
# Out:
#          city  temperature  humidity        date      city       Job  Salary
# 0     newyork         32.0      61.0  05-02-2017  New York  Software   12000
# 1  washington         14.0      65.0  05-03-2018  New York  Hardware   11500
# 2   newjersey         25.0      68.0  06-02-2017  New York  Mechanic   13000
# 3    illinois         31.0      61.0  07-02-2017  New York      Chef   14000
# 4         NaN          NaN       NaN  20-02-2017     Paris  Hardware   12500
# 5         NaN          NaN       NaN  21-02-2018     Paris  Mechanic   13500
# 6         NaN          NaN       NaN  21-05-2018     Paris      Chef   11000
# 7         NaN          NaN       NaN  21-05-2018    London  Software   15000
# 8         NaN          NaN       NaN  05-03-2018    London      Chef   12000
# 9         NaN          NaN       NaN  05-02-2017    London  Mechanic   14500

# %%
new_df
# Out:
# <function __main__.<lambda>(anystring)>

# %%
new_df
# Out:
# <function __main__.<lambda>(anystring)>

# %%
# how to convert the key word 
col= map(lambda x: x.lower(),new_df.columns)
new_df.columns=list(col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-8db462b888d4> in <module>
# ----> 1 col= map(lambda x: x.lower(),new_df.columns)
#       2 new_df.columns=list(col)
#
# AttributeError: 'function' object has no attribute 'columns'
